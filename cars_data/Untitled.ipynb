# %%
import pandas as pd

# %%
data = pd.read_excel(r'C:\Users\HP\Desktop\SDP\Used-Car-Price-Predictor\cars_data\tableau_final_final.xlsx')

# %%
data.head()
# Out:
#   car_name         Unnamed: 1  yr_mfr fuel_type  kms_run  sale_price   city  \
# 0   maruti       maruti swift    2015    petrol     8063      386399  noida
# 1   maruti    maruti alto 800    2016    petrol    23104      265499  noida
# 2  hyundai  hyundai grand i10    2017    petrol    23402      477699  noida
# 3   maruti       maruti swift    2013    diesel    39124      307999  noida
# 4  hyundai  hyundai grand i10    2015    petrol    22116      361499  noida
#
#    times_viewed  body_type transmission  ... total_owners  broker_quote  \
# 0         18715  hatchback       manual  ...            2        397677
# 1          2676  hatchback       manual  ...            1        272935
# 2           609  hatchback       manual  ...            1        469605
# 3          6511  hatchback       manual  ...            1        294262
# 4          3225  hatchback       manual  ...            1        360716
#
#   original_price car_rating            ad_created_on fitness_certificate  \
# ...
